# %%
from pyspark.sql import SparkSession, Row
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, LongType
from pyspark.sql.functions import col, count, desc, count_distinct, broadcast, concat, lit, upper

# %%
# SparkSession Definition
spark = SparkSession.builder.appName("Pyspark Overview").master("local[*]").getOrCreate()
# Out:
# 23/06/15 04:15:44 WARN Utils: Your hostname, MacBook-Air-de-Gabriel.local resolves to a loopback address: 127.0.0.1; using 192.168.1.9 instead (on interface en0)
# 23/06/15 04:15:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/06/15 04:15:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# #### Spark Configuration

# %%
spark.conf.get("spark.sql.autoBroadcastJoinThreshold")
# Out:
# '10485760b'

# %%
#Set Threshold limit of size in bytes of a DataFrame to broadcast
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", 10485760)

#Disable broadcast Join
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", 1)

# %% [markdown]
# ### Files Manipulating

# %%
spark.read.csv("../dataset/csv_data/olist_customers_dataset.csv", inferSchema=True, header=True).show()

# %%
spark.read \
    .format("csv") \
    .options(header=True) \
    .options(inferSchema=True) \
    .csv("../dataset/csv_data/olist_customers_dataset.csv").show()
# Out:
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|                   14409|              franca|            SP|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|                    9790|sao bernardo do c...|            SP|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|                    1151|           sao paulo|            SP|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|                    8775|     mogi das cruzes|            SP|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|                   13056|            campinas|            SP|
# |879864dab9bc30475...|4c93744516667ad3b...|                   89254|      jaragua do sul|            SC|
# |fd826e7cf63160e53...|addec96d2e059c80c...|                    4534|           sao paulo|            SP|
# |5e274e7a0c3809e14...|57b2a98a409812fe9...|                   35182|             timoteo|            MG|
# |5adf08e34b2e99398...|1175e95fb47ddff9d...|                   81560|            curitiba|            PR|
# |4b7139f34592b3a31...|9afe194fb833f79e3...|                   30575|      belo horizonte|            MG|
# |9fb35e4ed6f0a14a4...|2a7745e1ed516b289...|                   39400|       montes claros|            MG|
# |5aa9e4fdd4dfd2095...|2a46fb94aef5cbeeb...|                   20231|      rio de janeiro|            RJ|
# |b2d1536598b73a9ab...|918dc87cd72cd9f6e...|                   18682|    lencois paulista|            SP|
# |eabebad39a88bb6f5...|295c05e81917928d7...|                    5704|           sao paulo|            SP|
# |1f1c7bf1c9b041b29...|3151a81801c838636...|                   95110|       caxias do sul|            RS|
# |206f3129c0e4d7d0b...|21f748a16f4e1688a...|                   13412|          piracicaba|            SP|
# |a7c125a0a07b75146...|5c2991dbd08bbf3cf...|                   22750|      rio de janeiro|            RJ|
# |c5c61596a3b6bd0ce...|b6e99561fe6f34a55...|                    7124|           guarulhos|            SP|
# |9b8ce803689b3562d...|7f3a72e8f988c6e73...|                    5416|           sao paulo|            SP|
# |49d0ea0986edde72d...|3e6fd6b2f0d499456...|                   68485|              pacaja|            PA|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# only showing top 20 rows

# %%
df_parquet = spark.read.parquet("../dataset/parquet_data/olist_customers_dataset.parquet")
df_parquet.show()
df_parquet.printSchema()
# Out:
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|                   14409|              franca|            SP|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|                    9790|sao bernardo do c...|            SP|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|                    1151|           sao paulo|            SP|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|                    8775|     mogi das cruzes|            SP|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|                   13056|            campinas|            SP|
# |879864dab9bc30475...|4c93744516667ad3b...|                   89254|      jaragua do sul|            SC|
# |fd826e7cf63160e53...|addec96d2e059c80c...|                    4534|           sao paulo|            SP|
# |5e274e7a0c3809e14...|57b2a98a409812fe9...|                   35182|             timoteo|            MG|
# |5adf08e34b2e99398...|1175e95fb47ddff9d...|                   81560|            curitiba|            PR|
# |4b7139f34592b3a31...|9afe194fb833f79e3...|                   30575|      belo horizonte|            MG|
# |9fb35e4ed6f0a14a4...|2a7745e1ed516b289...|                   39400|       montes claros|            MG|
# |5aa9e4fdd4dfd2095...|2a46fb94aef5cbeeb...|                   20231|      rio de janeiro|            RJ|
# |b2d1536598b73a9ab...|918dc87cd72cd9f6e...|                   18682|    lencois paulista|            SP|
# |eabebad39a88bb6f5...|295c05e81917928d7...|                    5704|           sao paulo|            SP|
# |1f1c7bf1c9b041b29...|3151a81801c838636...|                   95110|       caxias do sul|            RS|
# |206f3129c0e4d7d0b...|21f748a16f4e1688a...|                   13412|          piracicaba|            SP|
# |a7c125a0a07b75146...|5c2991dbd08bbf3cf...|                   22750|      rio de janeiro|            RJ|
# |c5c61596a3b6bd0ce...|b6e99561fe6f34a55...|                    7124|           guarulhos|            SP|
# |9b8ce803689b3562d...|7f3a72e8f988c6e73...|                    5416|           sao paulo|            SP|
# |49d0ea0986edde72d...|3e6fd6b2f0d499456...|                   68485|              pacaja|            PA|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# only showing top 20 rows
#
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: long (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %%
parquet_squema = StructType([
    StructField('customer_id', StringType(), False),
    StructField('customer_unique_id', StringType(), False),
    StructField('customer_zip_code_prefix', LongType(), False),
    StructField('customer_city', StringType(), True),
    StructField('customer_state', StringType(), True)
])

df_parquet_squema = spark.read.schema(parquet_squema).parquet("../dataset/parquet_data/olist_customers_dataset.parquet")
df_parquet_squema.show()
df_parquet_squema.printSchema()
# Out:
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|                   14409|              franca|            SP|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|                    9790|sao bernardo do c...|            SP|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|                    1151|           sao paulo|            SP|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|                    8775|     mogi das cruzes|            SP|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|                   13056|            campinas|            SP|
# |879864dab9bc30475...|4c93744516667ad3b...|                   89254|      jaragua do sul|            SC|
# |fd826e7cf63160e53...|addec96d2e059c80c...|                    4534|           sao paulo|            SP|
# |5e274e7a0c3809e14...|57b2a98a409812fe9...|                   35182|             timoteo|            MG|
# |5adf08e34b2e99398...|1175e95fb47ddff9d...|                   81560|            curitiba|            PR|
# |4b7139f34592b3a31...|9afe194fb833f79e3...|                   30575|      belo horizonte|            MG|
# |9fb35e4ed6f0a14a4...|2a7745e1ed516b289...|                   39400|       montes claros|            MG|
# |5aa9e4fdd4dfd2095...|2a46fb94aef5cbeeb...|                   20231|      rio de janeiro|            RJ|
# |b2d1536598b73a9ab...|918dc87cd72cd9f6e...|                   18682|    lencois paulista|            SP|
# |eabebad39a88bb6f5...|295c05e81917928d7...|                    5704|           sao paulo|            SP|
# |1f1c7bf1c9b041b29...|3151a81801c838636...|                   95110|       caxias do sul|            RS|
# |206f3129c0e4d7d0b...|21f748a16f4e1688a...|                   13412|          piracicaba|            SP|
# |a7c125a0a07b75146...|5c2991dbd08bbf3cf...|                   22750|      rio de janeiro|            RJ|
# |c5c61596a3b6bd0ce...|b6e99561fe6f34a55...|                    7124|           guarulhos|            SP|
# |9b8ce803689b3562d...|7f3a72e8f988c6e73...|                    5416|           sao paulo|            SP|
# |49d0ea0986edde72d...|3e6fd6b2f0d499456...|                   68485|              pacaja|            PA|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# only showing top 20 rows
#
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: long (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %% [markdown]
# #### Dataframe: Criação

# %%
columns = ["language","users_count"]
data = [("Java", "20000"), ("Python", "100000"), ("Scala", "3000")]
data_dict = [{'name': 'Alice', 'age': 1}, {'name': 'Gabriel', 'age': 34}]

# Criar a partir de lista
df = spark.createDataFrame(data, columns)
df.show()
# Criar a partir de RDD
rdd = spark.sparkContext.parallelize(data)
rdd.toDF(columns).show()
# Criar a partir de RDD com createDataFrame
spark.createDataFrame(rdd).show()
# Criar a partir de RDD com createDataFrame
spark.createDataFrame(rdd).toDF(*columns).show()
# Criar a partir de RDD com createDataFrame
spark.createDataFrame(rdd, columns).show()
# Criar a partir de dicionário
spark.createDataFrame(data_dict).show()
# Out:
# +--------+-----------+
# |language|users_count|
# +--------+-----------+
# |    Java|      20000|
# |  Python|     100000|
# |   Scala|       3000|
# +--------+-----------+
#
# +--------+-----------+
# |language|users_count|
# +--------+-----------+
# |    Java|      20000|
# |  Python|     100000|
# |   Scala|       3000|
# +--------+-----------+
#
# +------+------+
# |    _1|    _2|
# +------+------+
# |  Java| 20000|
# |Python|100000|
# | Scala|  3000|
# +------+------+
#
# +--------+-----------+
# |language|users_count|
# +--------+-----------+
# |    Java|      20000|
# |  Python|     100000|
# |   Scala|       3000|
# +--------+-----------+
#
# +--------+-----------+
# |language|users_count|
# +--------+-----------+
# |    Java|      20000|
# |  Python|     100000|
# |   Scala|       3000|
# +--------+-----------+
#
# +---+-------+
# |age|   name|
# +---+-------+
# |  1|  Alice|
# | 34|Gabriel|
# +---+-------+

# %% [markdown]
# #### Dataframe: Manipulação

# %%
df = spark.read.parquet("../dataset/parquet_data/olist_customers_dataset.parquet")

# %%
# Selecionar Colunas
df.select('customer_id', 'customer_unique_id').show()
# Out:
# +--------------------+--------------------+
# |         customer_id|  customer_unique_id|
# +--------------------+--------------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|
# |879864dab9bc30475...|4c93744516667ad3b...|
# |fd826e7cf63160e53...|addec96d2e059c80c...|
# |5e274e7a0c3809e14...|57b2a98a409812fe9...|
# |5adf08e34b2e99398...|1175e95fb47ddff9d...|
# |4b7139f34592b3a31...|9afe194fb833f79e3...|
# |9fb35e4ed6f0a14a4...|2a7745e1ed516b289...|
# |5aa9e4fdd4dfd2095...|2a46fb94aef5cbeeb...|
# |b2d1536598b73a9ab...|918dc87cd72cd9f6e...|
# |eabebad39a88bb6f5...|295c05e81917928d7...|
# |1f1c7bf1c9b041b29...|3151a81801c838636...|
# |206f3129c0e4d7d0b...|21f748a16f4e1688a...|
# |a7c125a0a07b75146...|5c2991dbd08bbf3cf...|
# |c5c61596a3b6bd0ce...|b6e99561fe6f34a55...|
# |9b8ce803689b3562d...|7f3a72e8f988c6e73...|
# |49d0ea0986edde72d...|3e6fd6b2f0d499456...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
# Contar os registros de uma coluna
df.select(count('customer_id').alias("ct")).show()
# Out:
# +-----+
# |   ct|
# +-----+
# |99441|
# +-----+

# %%
# Contar os registros por groupBy
df.groupBy('customer_state', 'customer_city') \
    .agg(count("*").alias("ct")) \
    .sort(desc("ct")) \
    .where(col("ct") >= 1000) \
    .show()
# Out:
# +--------------+--------------+-----+
# |customer_state| customer_city|   ct|
# +--------------+--------------+-----+
# |            SP|     sao paulo|15540|
# |            RJ|rio de janeiro| 6882|
# |            MG|belo horizonte| 2773|
# |            DF|      brasilia| 2131|
# |            PR|      curitiba| 1521|
# |            SP|      campinas| 1444|
# |            RS|  porto alegre| 1379|
# |            BA|      salvador| 1245|
# |            SP|     guarulhos| 1189|
# +--------------+--------------+-----+

# %%
# Filtrar os resgistros antes de Agregar
df.select('customer_state', 'customer_city') \
    .where(col('customer_state') != "SP") \
    .groupBy('customer_state', 'customer_city') \
    .agg(count("*").alias("ct")) \
    .sort(desc("ct")) \
    .where(col("ct") >= 1000) \
    .show()
# Out:
# +--------------+--------------+----+
# |customer_state| customer_city|  ct|
# +--------------+--------------+----+
# |            RJ|rio de janeiro|6882|
# |            MG|belo horizonte|2773|
# |            DF|      brasilia|2131|
# |            PR|      curitiba|1521|
# |            RS|  porto alegre|1379|
# |            BA|      salvador|1245|
# +--------------+--------------+----+

# %%
# Join múltiplas tabelas com broadcast e método de agregação
dim_customer = spark.read.parquet("../dataset/parquet_data/olist_customers_dataset.parquet")
fact_order = spark.read.parquet("../dataset/parquet_data/olist_orders_dataset.parquet")

fact_order.join(dim_customer, fact_order.customer_id == dim_customer.customer_id, 'inner') \
    .select( \
        fact_order.order_id.alias("cupom_id"), \
        dim_customer.customer_state \
    ) \
    .groupBy("customer_state").agg(count("*").alias("ct")) \
    .sort(desc("ct")) \
    .show()
# Out:
# [Stage 53:>                                                         (0 + 6) / 6]
# +--------------+-----+
# |customer_state|   ct|
# +--------------+-----+
# |            SP|41746|
# |            RJ|12852|
# |            MG|11635|
# |            RS| 5466|
# |            PR| 5045|
# |            SC| 3637|
# |            BA| 3380|
# |            DF| 2140|
# |            ES| 2033|
# |            GO| 2020|
# |            PE| 1652|
# |            CE| 1336|
# |            PA|  975|
# |            MT|  907|
# |            MA|  747|
# |            MS|  715|
# |            PB|  536|
# |            PI|  495|
# |            RN|  485|
# |            AL|  413|
# +--------------+-----+
# only showing top 20 rows

# %%
# Com broadcast
fact_order.join(broadcast(dim_customer), fact_order.customer_id == dim_customer.customer_id, 'inner') \
    .select( \
        fact_order.order_id.alias("cupom_id"), \
        dim_customer.customer_state \
    ) \
    .groupBy("customer_state").agg(count("*").alias("ct")) \
    .sort(desc("ct")) \
    .explain()

# Sem broadcast
fact_order.join(dim_customer, fact_order.customer_id == dim_customer.customer_id, 'inner') \
    .select( \
        fact_order.order_id.alias("cupom_id"), \
        dim_customer.customer_state \
    ) \
    .groupBy("customer_state").agg(count("*").alias("ct")) \
    .sort(desc("ct")) \
    .explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [ct#856L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(ct#856L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=1230]
#       +- HashAggregate(keys=[customer_state#545], functions=[count(1)])
#          +- Exchange hashpartitioning(customer_state#545, 200), ENSURE_REQUIREMENTS, [plan_id=1227]
#             +- HashAggregate(keys=[customer_state#545], functions=[partial_count(1)])
#                +- Project [customer_state#545]
#                   +- BroadcastHashJoin [customer_id#552], [customer_id#541], Inner, BuildRight, false
#                      :- Filter isnotnull(customer_id#552)
#                      :  +- FileScan parquet [customer_id#552] Batched: true, DataFilters: [isnotnull(customer_id#552)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/gabrielbossardi/Documents/Projects/pyspark-overview/datase..., PartitionFilters: [], PushedFilters: [IsNotNull(customer_id)], ReadSchema: struct<customer_id:string>
#                      +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=1222]
#                         +- Filter isnotnull(customer_id#541)
#                            +- FileScan parquet [customer_id#541,customer_state#545] Batched: true, DataFilters: [isnotnull(customer_id#541)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/gabrielbossardi/Documents/Projects/pyspark-overview/datase..., PartitionFilters: [], PushedFilters: [IsNotNull(customer_id)], ReadSchema: struct<customer_id:string,customer_state:string>
#
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [ct#893L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(ct#893L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=1284]
#       +- HashAggregate(keys=[customer_state#545], functions=[count(1)])
#          +- Exchange hashpartitioning(customer_state#545, 200), ENSURE_REQUIREMENTS, [plan_id=1281]
#             +- HashAggregate(keys=[customer_state#545], functions=[partial_count(1)])
#                +- Project [customer_state#545]
#                   +- SortMergeJoin [customer_id#552], [customer_id#541], Inner
#                      :- Sort [customer_id#552 ASC NULLS FIRST], false, 0
#                      :  +- Exchange hashpartitioning(customer_id#552, 200), ENSURE_REQUIREMENTS, [plan_id=1273]
#                      :     +- Filter isnotnull(customer_id#552)
#                      :        +- FileScan parquet [customer_id#552] Batched: true, DataFilters: [isnotnull(customer_id#552)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/gabrielbossardi/Documents/Projects/pyspark-overview/datase..., PartitionFilters: [], PushedFilters: [IsNotNull(customer_id)], ReadSchema: struct<customer_id:string>
#                      +- Sort [customer_id#541 ASC NULLS FIRST], false, 0
#                         +- Exchange hashpartitioning(customer_id#541, 200), ENSURE_REQUIREMENTS, [plan_id=1274]
#                            +- Filter isnotnull(customer_id#541)
#                               +- FileScan parquet [customer_id#541,customer_state#545] Batched: true, DataFilters: [isnotnull(customer_id#541)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/gabrielbossardi/Documents/Projects/pyspark-overview/datase..., PartitionFilters: [], PushedFilters: [IsNotNull(customer_id)], ReadSchema: struct<customer_id:string,customer_state:string>

# %%
# union
dim_customer.select(count("*").alias("ct")).show()
dim_customer.union(dim_customer).agg(count("*").alias("ct")).show()
dim_customer.union(dim_customer).distinct().agg(count("*").alias("ct")).show()
# Out:
# +-----+
# |   ct|
# +-----+
# |99441|
# +-----+
#
# +------+
# |    ct|
# +------+
# |198882|
# +------+
#
# +-----+
# |   ct|
# +-----+
# |99441|
# +-----+

# %%
df_states = dim_customer.select("customer_state", "customer_city").distinct()
df_states.show()

dim_city = df_states.rdd.map(lambda x: (x[0], f'Cidade: {x[1]}, do Estado de: {x[0]}'))
dim_city.toDF(["customer_state", "customer_city"]).show(truncate=False)
# Out:
# +--------------+--------------------+
# |customer_state|       customer_city|
# +--------------+--------------------+
# |            SP|         carapicuiba|
# |            PR|            marialva|
# |            SC|            saudades|
# |            SP|            guaicara|
# |            SP|             ubatuba|
# |            RO|sao francisco do ...|
# |            PR|           pranchita|
# |            BA|             sapeacu|
# |            PE|               xexeu|
# |            MG|   santana da vargem|
# |            SP|  santa rita d'oeste|
# |            MA|              grajau|
# |            MS|          deodapolis|
# |            MG|         montalvania|
# |            MG|  ponto do marambaia|
# |            PI|     nova santa rita|
# |            SP|            boraceia|
# |            MS|              tacuru|
# |            MG|           ituiutaba|
# |            GO|               jatai|
# +--------------+--------------------+
# only showing top 20 rows
#
# +--------------+--------------------------------------------------+
# |customer_state|customer_city                                     |
# +--------------+--------------------------------------------------+
# |SP            |Cidade: carapicuiba, do Estado de: SP             |
# |PR            |Cidade: marialva, do Estado de: PR                |
# |SC            |Cidade: saudades, do Estado de: SC                |
# |SP            |Cidade: guaicara, do Estado de: SP                |
# |SP            |Cidade: ubatuba, do Estado de: SP                 |
# |RO            |Cidade: sao francisco do guapore, do Estado de: RO|
# |PR            |Cidade: pranchita, do Estado de: PR               |
# |BA            |Cidade: sapeacu, do Estado de: BA                 |
# |PE            |Cidade: xexeu, do Estado de: PE                   |
# |MG            |Cidade: santana da vargem, do Estado de: MG       |
# |SP            |Cidade: santa rita d'oeste, do Estado de: SP      |
# |MA            |Cidade: grajau, do Estado de: MA                  |
# |MS            |Cidade: deodapolis, do Estado de: MS              |
# |MG            |Cidade: montalvania, do Estado de: MG             |
# |MG            |Cidade: ponto do marambaia, do Estado de: MG      |
# |PI            |Cidade: nova santa rita, do Estado de: PI         |
# |SP            |Cidade: boraceia, do Estado de: SP                |
# |MS            |Cidade: tacuru, do Estado de: MS                  |
# |MG            |Cidade: ituiutaba, do Estado de: MG               |
# |GO            |Cidade: jatai, do Estado de: GO                   |
# +--------------+--------------------------------------------------+
# only showing top 20 rows

# %%
df_states.withColumn("customer_city", concat(lit('Cidade: '), col("customer_city"))).show()
# Out:
# +--------------+--------------------+
# |customer_state|       customer_city|
# +--------------+--------------------+
# |            SP| Cidade: carapicuiba|
# |            PR|    Cidade: marialva|
# |            SC|    Cidade: saudades|
# |            SP|    Cidade: guaicara|
# |            SP|     Cidade: ubatuba|
# |            RO|Cidade: sao franc...|
# |            PR|   Cidade: pranchita|
# |            BA|     Cidade: sapeacu|
# |            PE|       Cidade: xexeu|
# |            MG|Cidade: santana d...|
# |            SP|Cidade: santa rit...|
# |            MA|      Cidade: grajau|
# |            MS|  Cidade: deodapolis|
# |            MG| Cidade: montalvania|
# |            MG|Cidade: ponto do ...|
# |            PI|Cidade: nova sant...|
# |            SP|    Cidade: boraceia|
# |            MS|      Cidade: tacuru|
# |            MG|   Cidade: ituiutaba|
# |            GO|       Cidade: jatai|
# +--------------+--------------------+
# only showing top 20 rows

# %%
df_states.where(col("customer_state") == "SP").foreach(lambda x: print(f'Cidade: {x[1]}'))
# Out:
# Cidade: carapicuiba
# Cidade: guaicara
# Cidade: ubatuba
# Cidade: santa rita d'oeste
# Cidade: boraceia
# Cidade: aracariguama
# Cidade: borborema
# Cidade: campo limpo paulista
# Cidade: sao caetano do sul
# Cidade: taubate
# Cidade: dracena
# Cidade: juquia
# Cidade: urania
# Cidade: elias fausto
# Cidade: sarapui
# Cidade: dobrada
# Cidade: santa barbara d oeste
# Cidade: porangaba
# Cidade: guariroba
# Cidade: guariba
# Cidade: itatiba
# Cidade: nova odessa
# Cidade: pirapozinho
# Cidade: piquerobi
# Cidade: campinas
# Cidade: porto ferreira
# Cidade: adolfo
# Cidade: tres fronteiras
# Cidade: santa cruz das palmeiras
# Cidade: bandeirantes d'oeste
# Cidade: ferraz de vasconcelos
# Cidade: aguai
# Cidade: cipo-guacu
# Cidade: matao
# Cidade: palestina
# Cidade: paranapanema
# Cidade: capela do alto
# Cidade: coroados
# Cidade: sao paulo
# Cidade: birigui
# Cidade: urupes
# Cidade: rio das pedras
# Cidade: rubineia
# Cidade: olimpia
# Cidade: sao miguel arcanjo
# Cidade: torrinha
# Cidade: promissao
# Cidade: emilianopolis
# Cidade: aramina
# Cidade: jeriquara
# Cidade: pedreira
# Cidade: brodowski
# Cidade: sao lourenco da serra
# Cidade: onda verde
# Cidade: tapinas
# Cidade: ribeira
# Cidade: icem
# Cidade: analandia
# Cidade: tupa
# Cidade: votorantim
# Cidade: dumont
# Cidade: irapuru
# Cidade: araraquara
# Cidade: rancharia
# Cidade: ilha solteira
# Cidade: espirito santo do pinhal
# Cidade: castilho
# Cidade: vera cruz
# Cidade: cachoeira paulista
# Cidade: guaira
# Cidade: arandu
# Cidade: barueri
# Cidade: pedra bela
# Cidade: mendonca
# Cidade: santa isabel
# Cidade: lindoia
# Cidade: auriflama
# Cidade: piracicaba
# Cidade: lorena
# Cidade: mococa
# Cidade: varzea paulista
# Cidade: salesopolis
# Cidade: vista alegre do alto
# Cidade: anhumas
# Cidade: hortolandia
# Cidade: rubiacea
# Cidade: guararapes
# Cidade: nossa senhora do remedio
# Cidade: santa ernestina
# Cidade: holambra ii
# Cidade: lourdes
# Cidade: embu
# Cidade: fernando prestes
# Cidade: oscar bressane
# Cidade: macedonia
# Cidade: ribeirao bonito
# Cidade: populina
# Cidade: paulinia
# Cidade: sao carlos
# Cidade: mogi-guacu
# Cidade: santana de parnaiba
# Cidade: monte alto
# Cidade: gabriel monteiro
# Cidade: itanhaem
# Cidade: sud mennucci
# Cidade: sao pedro
# Cidade: lucelia
# Cidade: tremembe
# Cidade: ribeirao pires
# Cidade: paraguacu paulista
# Cidade: cajati
# Cidade: irapua
# Cidade: pinheiros
# Cidade: batatais
# Cidade: brauna
# Cidade: itapura
# Cidade: ibira
# Cidade: paraiso
# Cidade: sao sebastiao da serra
# Cidade: nova luzitania
# Cidade: tuiuti
# Cidade: brotas
# Cidade: cristais paulista
# Cidade: cunha
# Cidade: indiana
# Cidade: jandira
# Cidade: alvaro de carvalho
# Cidade: agisse
# Cidade: cruzeiro
# Cidade: irape
# Cidade: jaborandi
# Cidade: areiopolis
# Cidade: itapira
# Cidade: planalto
# Cidade: jau
# Cidade: itarare
# Cidade: nhandeara
# Cidade: itapetininga
# Cidade: herculandia
# Cidade: valparaiso
# Cidade: pardinho
# Cidade: pontes gestal
# Cidade: lencois paulista
# Cidade: itajobi
# Cidade: guatapara
# Cidade: venda branca
# Cidade: braganca paulista
# Cidade: embu das artes
# Cidade: panorama
# Cidade: itabera
# Cidade: itobi
# Cidade: barretos
# Cidade: quintana
# Cidade: juquitiba
# Cidade: angatuba
# Cidade: ocaucu
# Cidade: sao sebastiao
# Cidade: catigua
# Cidade: pinhalzinho
# Cidade: sao jose do rio preto
# Cidade: chavantes
# Cidade: sarutaia
# Cidade: echapora
# Cidade: cardoso
# Cidade: pontalinda
# Cidade: palmeira d oeste
# Cidade: natividade da serra
# Cidade: getulina
# Cidade: botucatu
# Cidade: tabatinga
# Cidade: jacupiranga
# Cidade: cananeia
# Cidade: nova independencia
# Cidade: piquete
# Cidade: neves paulista
# Cidade: pontal
# Cidade: jamaica
# Cidade: cafelandia
# Cidade: nova europa
# Cidade: franco da rocha
# Cidade: jacarei
# Cidade: fartura
# Cidade: santo anastacio
# Cidade: pedregulho
# Cidade: santa clara d'oeste
# Cidade: ariranha
# Cidade: maristela
# Cidade: franca
# Cidade: aluminio
# Cidade: garca
# Cidade: riversul
# Cidade: aguas de lindoia
# Cidade: cordeiropolis
# Cidade: candido mota
# Cidade: potim
# Cidade: alvares florence
# Cidade: lutecia
# Cidade: presidente bernardes
# Cidade: bocaina
# Cidade: gaviao peixoto
# Cidade: sertaozinho
# Cidade: santa adelia
# Cidade: mongagua
# Cidade: iacri
# Cidade: general salgado
# Cidade: sumare
# Cidade: marinopolis
# Cidade: jardinopolis
# Cidade: poloni
# Cidade: mariapolis
# Cidade: pedro de toledo
# Cidade: murutinga do sul
# Cidade: salto grande
# Cidade: joanopolis
# Cidade: itaoca
# Cidade: valinhos
# Cidade: cajamar
# Cidade: duartina
# Cidade: presidente alves
# Cidade: alvares machado
# Cidade: itapui
# Cidade: ilhabela
# Cidade: estiva gerbi
# Cidade: cassia dos coqueiros
# Cidade: santa rita do passa quatro
# Cidade: cedral
# Cidade: ibate
# Cidade: pacaembu
# Cidade: jose bonifacio
# Cidade: ribeirao branco
# Cidade: euclides da cunha paulista
# Cidade: piedade
# Cidade: corumbatai
# Cidade: julio mesquita
# Cidade: osvaldo cruz
# Cidade: ibirarema
# Cidade: miguelopolis
# Cidade: cerquilho
# Cidade: suzano
# Cidade: jambeiro
# Cidade: itaju
# Cidade: luiziania
# Cidade: tupi paulista
# Cidade: oriente
# Cidade: oleo
# Cidade: taiacu
# Cidade: vargem grande paulista
# Cidade: anhembi
# Cidade: bom jesus dos perdoes
# Cidade: pariquera-acu
# Cidade: santo antonio do jardim
# Cidade: conchal
# Cidade: sales
# Cidade: sao joao de iracema
# Cidade: inubia paulista
# Cidade: morungaba
# Cidade: andradina
# Cidade: bofete
# Cidade: altinopolis
# Cidade: serra azul
# Cidade: ituverava
# Cidade: paranapua
# Cidade: adamantina
# Cidade: potirendaba
# Cidade: santa mercedes
# Cidade: orindiuva
# Cidade: glicerio
# Cidade: patrocinio paulista
# Cidade: itaporanga
# Cidade: clementina
# Cidade: balbinos
# Cidade: bertioga
# Cidade: guaracai
# Cidade: taruma
# Cidade: morro agudo
# Cidade: macatuba
# Cidade: floreal
# Cidade: sao roque
# Cidade: atibaia
# Cidade: socorro
# Cidade: alfredo marcondes
# Cidade: avare
# Cidade: santo antonio de posse
# Cidade: nuporanga
# Cidade: queiroz
# Cidade: pereira barreto
# Cidade: mirante do paranapanema
# Cidade: bernardino de campos
# Cidade: tarabai
# Cidade: tejupa
# Cidade: rio claro
# Cidade: itai
# Cidade: vargem grande do sul
# Cidade: ouro verde
# Cidade: igaracu do tiete
# Cidade: jumirim
# Cidade: tapiratiba
# Cidade: orlandia
# Cidade: ilha comprida
# Cidade: nipoa
# Cidade: buritizal
# Cidade: artur nogueira
# Cidade: sao joao da boa vista
# Cidade: cosmopolis
# Cidade: sao francisco
# Cidade: santo andre
# Cidade: boa esperanca do sul
# Cidade: luis antonio
# Cidade: itapeva
# Cidade: santa maria da serra
# Cidade: sao bernardo do campo
# Cidade: maua
# Cidade: iepe
# Cidade: descalvado
# Cidade: paraibuna
# Cidade: sabino
# Cidade: bananal
# Cidade: santo antonio da alegria
# Cidade: miracatu
# Cidade: pereiras
# Cidade: pirapora do bom jesus
# Cidade: arapei
# Cidade: tecainda
# Cidade: campos do jordao
# Cidade: engenheiro coelho
# Cidade: guarei
# Cidade: palmital
# Cidade: sao manuel
# Cidade: ribeirao do sul
# Cidade: pedrinhas paulista
# Cidade: bento de abreu
# Cidade: bilac
# Cidade: joao ramalho
# Cidade: guarapua
# Cidade: mogi-mirim
# Cidade: ibitinga
# Cidade: louveira
# Cidade: guararema
# Cidade: pirangi
# Cidade: lavinia
# Cidade: santa salete
# Cidade: cabralia paulista
# Cidade: tabapua
# Cidade: reginopolis
# Cidade: guapiacu
# Cidade: diadema
# Cidade: cesario lange
# Cidade: presidente venceslau
# Cidade: cravinhos
# Cidade: salto de pirapora
# Cidade: bonfim paulista
# Cidade: taquaritinga
# Cidade: uchoa
# Cidade: votuporanga
# Cidade: coronel macedo
# Cidade: ibitiuva
# Cidade: sete barras
# Cidade: monte azul paulista
# Cidade: rio grande da serra
# Cidade: pirajui
# Cidade: florinia
# Cidade: elisiario
# Cidade: embauba
# Cidade: tambau
# Cidade: ibiuna
# Cidade: santa cruz da conceicao
# Cidade: santa albertina
# Cidade: santa gertrudes
# Cidade: holambra
# Cidade: parapua
# Cidade: queluz
# Cidade: bastos
# Cidade: severinia
# Cidade: flora rica
# Cidade: mineiros do tiete
# Cidade: presidente epitacio
# Cidade: igarapava
# Cidade: rechan
# Cidade: terra roxa
# Cidade: catanduva
# Cidade: mogi mirim
# Cidade: colombia
# Cidade: zacarias
# Cidade: assis
# Cidade: sao pedro do turvo
# Cidade: estrela d'oeste
# Cidade: monteiro lobato
# Cidade: meridiano
# Cidade: taboao da serra
# Cidade: itariri
# Cidade: engenheiro balduino
# Cidade: cubatao
# Cidade: maracai
# Cidade: nova guataporanga
# Cidade: leme
# Cidade: ipaussu
# Cidade: arealva
# Cidade: santo expedito
# Cidade: cerqueira cesar
# Cidade: rafard
# Cidade: martinopolis
# Cidade: cajuru
# Cidade: penapolis
# Cidade: ipigua
# Cidade: santa rosa de viterbo
# Cidade: novo horizonte
# Cidade: itapirapua paulista
# Cidade: poa
# Cidade: tiete
# Cidade: iaras
# Cidade: motuca
# Cidade: pompeia
# Cidade: caiua
# Cidade: santa fe do sul
# Cidade: aracatuba
# Cidade: mirassol
# Cidade: nazare paulista
# Cidade: aguas de sao pedro
# Cidade: aparecida
# Cidade: taquarivai
# Cidade: turmalina
# Cidade: guzolandia
# Cidade: sao vicente
# Cidade: bebedouro
# Cidade: pederneiras
# Cidade: aruja
# Cidade: serra negra
# Cidade: sales oliveira
# Cidade: monte aprazivel
# Cidade: manduri
# Cidade: canitar
# Cidade: praia grande
# Cidade: vargem
# Cidade: lucianopolis
# Cidade: moncoes
# Cidade: pindamonhangaba
# Cidade: aguas da prata
# Cidade: avanhandava
# Cidade: narandiba
# Cidade: boituva
# Cidade: fernandopolis
# Cidade: quata
# Cidade: eldorado
# Cidade: sorocaba
# Cidade: sao jose da bela vista
# Cidade: sao jose do barreiro
# Cidade: fernao
# Cidade: ipero
# Cidade: nova canaa paulista
# Cidade: nantes
# Cidade: guaraci
# Cidade: tanabi
# Cidade: avai
# Cidade: barao ataliba nogueira
# Cidade: primavera
# Cidade: santa branca
# Cidade: iguape
# Cidade: mirandopolis
# Cidade: peruibe
# Cidade: sao sebastiao da grama
# Cidade: laranjal paulista
# Cidade: pedranopolis
# Cidade: salto
# Cidade: cotia
# Cidade: taguai
# Cidade: espigao
# Cidade: jarinu
# Cidade: serrana
# Cidade: nova campina
# Cidade: redencao da serra
# Cidade: trabiju
# Cidade: aparecida de monte alto
# Cidade: sao jose dos campos
# Cidade: limeira
# Cidade: rinopolis
# Cidade: viradouro
# Cidade: silveiras
# Cidade: rincao
# Cidade: registro
# Cidade: capao bonito
# Cidade: iacanga
# Cidade: ipua
# Cidade: palmares paulista
# Cidade: caconde
# Cidade: pauliceia
# Cidade: mairipora
# Cidade: lagoinha
# Cidade: indiapora
# Cidade: agudos
# Cidade: piraju
# Cidade: jaci
# Cidade: roseira
# Cidade: botelho
# Cidade: pradopolis
# Cidade: estrela d oeste
# Cidade: americana
# Cidade: pilar do sul
# Cidade: pirassununga
# Cidade: jales
# Cidade: itupeva
# Cidade: americo brasiliense
# Cidade: palmeira d'oeste
# Cidade: santo antonio do pinhal
# Cidade: itapevi
# Cidade: apiai
# Cidade: ajapi
# Cidade: mairinque
# Cidade: taciba
# Cidade: mira estrela
# Cidade: iracemapolis
# Cidade: monte castelo
# Cidade: campina do monte alegre
# Cidade: santa cruz do rio pardo
# Cidade: itapolis
# Cidade: buri
# Cidade: candido rodrigues
# Cidade: paulistania
# Cidade: galia
# Cidade: bauru
# Cidade: dourado
# Cidade: igarata
# Cidade: paulo de faria
# Cidade: presidente prudente
# Cidade: guapiara
# Cidade: monte mor
# Cidade: jaguariuna
# Cidade: salmourao
# Cidade: barra do turvo
# Cidade: termas de ibira
# Cidade: araras
# Cidade: colina
# Cidade: ubirajara
# Cidade: americo de campos
# Cidade: porto feliz
# Cidade: pitangueiras
# Cidade: cabreuva
# Cidade: pongai
# Cidade: cajobi
# Cidade: macaubal
# Cidade: guaratingueta
# Cidade: charqueada
# Cidade: ouroeste
# Cidade: balsamo
# Cidade: junqueiropolis
# Cidade: teodoro sampaio
# Cidade: florida paulista
# Cidade: lins
# Cidade: jaboticabal
# Cidade: itaquaquecetuba
# Cidade: guara
# Cidade: taiuva
# Cidade: taquarituba
# Cidade: piracaia
# Cidade: marilia
# Cidade: alambari
# Cidade: mogi das cruzes
# Cidade: saltinho
# Cidade: bariri
# Cidade: casa branca
# Cidade: mombuca
# Cidade: divinolandia
# Cidade: francisco morato
# Cidade: buritama
# Cidade: quadra
# Cidade: santos
# Cidade: ourinhos
# Cidade: monte alegre do sul
# Cidade: caraguatatuba
# Cidade: jacare
# Cidade: barrinha
# Cidade: biritiba-mirim
# Cidade: sao luis do paraitinga
# Cidade: lupercio
# Cidade: caieiras
# Cidade: conchas
# Cidade: bora
# Cidade: piacatu
# Cidade: pindorama
# Cidade: valentim gentil
# Cidade: guarulhos
# Cidade: guaranta
# Cidade: estrela do norte
# Cidade: piratininga
# Cidade: sao jose do rio pardo
# Cidade: sao simao
# Cidade: itu
# Cidade: barra bonita
# Cidade: timburi
# Cidade: suzanapolis
# Cidade: sao bento do sapucai
# Cidade: capivari
# Cidade: cosmorama
# Cidade: riolandia
# Cidade: santa lucia
# Cidade: areias
# Cidade: vinhedo
# Cidade: tatui
# Cidade: nova granada
# Cidade: cruzalia
# Cidade: novais
# Cidade: magda
# Cidade: jundiai
# Cidade: embu-guacu
# Cidade: dois corregos
# Cidade: itirapina
# Cidade: rifaina
# Cidade: aparecida d'oeste
# Cidade: gastao vidigal
# Cidade: espirito santo do turvo
# Cidade: ribeirao preto
# Cidade: osasco
# Cidade: guaruja
# Cidade: santa barbara d'oeste
# Cidade: itatinga
# Cidade: parisi
# Cidade: bady bassitt
# Cidade: lavrinhas
# Cidade: tapirai
# Cidade: cacapava
# Cidade: aracoiaba da serra
# Cidade: indaiatuba
# Cidade: regente feijo
# Cidade: aguas de santa barbara
# Cidade: itapecerica da serra
# Cidade: amparo
# Cidade: aparecida de sao manuel
# Cidade: sao joaquim da barra
# Cidade: rosana
# Cidade: santo antonio do aracangua

# %% [markdown]
# #### SQL

# %%
df.createOrReplaceTempView("TEMP_DF")

query = """
SELECT
    customer_state,
    customer_city,
    COUNT(*) AS ct
FROM TEMP_DF
GROUP BY 1, 2
HAVING ct >= 1000
ORDER BY ct DESC
"""

spark.sql(query).show()
# Out:
# [Stage 341:============================>                            (1 + 1) / 2]
# +--------------+--------------+-----+
# |customer_state| customer_city|   ct|
# +--------------+--------------+-----+
# |            SP|     sao paulo|15540|
# |            RJ|rio de janeiro| 6882|
# |            MG|belo horizonte| 2773|
# |            DF|      brasilia| 2131|
# |            PR|      curitiba| 1521|
# |            SP|      campinas| 1444|
# |            RS|  porto alegre| 1379|
# |            BA|      salvador| 1245|
# |            SP|     guarulhos| 1189|
# +--------------+--------------+-----+

# %% [markdown]
# #### RDD: Criação

# %%
# Criar a partir de RDD
rdd = spark.sparkContext.parallelize(data)
rdd.toDF(columns).show()

# %%
# Criar RDD a partir de Row
Person = Row('code', 'count')
rdd2 = rdd.map(lambda r: Person(*r))
rdd2.collect()
# Out:
# [Row(code='Java', count='20000'),
#  Row(code='Python', count='100000'),
#  Row(code='Scala', count='3000')]

# %% [markdown]
# #### RDD: Transformação

# %%
rdd2.map(lambda r: 'Linguagem: ' + r['code']).collect()
# Out:
# ['Linguagem: Java', 'Linguagem: Python', 'Linguagem: Scala']

# %%
print(fact_order.rdd.getNumPartitions())

fact_order.rdd.mapPartitions(lambda it: [sum(len(row) for row in it)]).collect()

# %% [markdown]
# #### repartition() and Coalesce()

# %%
df.coalesce(<number>)
df.repartition(<number>)
df.coalesce(<number>)
df.repartition(<number>)

# %% [markdown]
# #### Python

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'
